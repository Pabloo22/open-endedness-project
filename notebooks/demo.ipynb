# %% [markdown]
# If you are using VS Code, install the Colab extension and select the "colab" kernel to run the code in this notebook.

# %%
# !pip install git+https://github.com/Pabloo22/open-endedness-project.git@jax_version
# Out:
# ...
#   Cloning https://github.com/Pabloo22/open-endedness-project.git to /tmp/pip-req-build-w5_16wdr
#   Running command git clone --filter=blob:none --quiet https://github.com/Pabloo22/open-endedness-project.git /tmp/pip-req-build-w5_16wdr
#   Resolved https://github.com/Pabloo22/open-endedness-project.git to commit 33b53c68b5a22156d9b03c587b8377a202d6594f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.1/410.1 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 176.1 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.6/86.6 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 133.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 66.7 MB/s eta 0:00:00
# ...

# %%
from crew.experiments.run_training import run_main_algo_training, TrainConfig


# Smoke-friendly local run configuration.
config = TrainConfig(
    train_seed=1,
    total_timesteps=100_000,
    env_id="Craftax-Classic-Symbolic-v1",
    achievement_ids_to_block=tuple(range(15)),  # Block the first n achievements for testing.
    training_mode="curriculum",  # "curriculum" or "baseline"
    selected_intrinsic_modules=("rnd",),
    baseline_fixed_training_alpha=(0.8, 0.2),  # Only used in baseline mode.
    num_envs_per_batch=64,
    num_steps_per_env=512,
    num_steps_per_update=256,
    eval_every_n_batches=2,
    eval_num_envs=64,
    eval_num_episodes=2,
    evaluation_alphas=((0.8, 0.2), (1.0, 0.0)),  # Only used in curriculum mode.
    update_epochs=1,
    num_minibatches=16,
    past_context_length=64,
    subsequence_length_in_loss_calculation=64,
    num_transformer_blocks=1,
    transformer_hidden_states_dim=64,
    qkv_features=64,
    head_hidden_dim=64,
    enable_wandb=True,
    is_timing_run=False,
)
run_main_algo_training(config=config, save_results=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_397/4122157999.py in <cell line: 0>()
# ----> 1 from crew.experiments.run_training import run_main_algo_training, TrainConfig
#       2
#       3
#       4 # Smoke-friendly local run configuration.
#       5 config = TrainConfig(
#
# /usr/local/lib/python3.12/dist-packages/crew/experiments/run_training.py in <module>
#       9
#      10 from crew.experiments.paths import build_trained_weights_path
# ---> 11 from crew.main_algo.baseline_main_loop import full_training_baseline
#      12 from crew.main_algo.config import TrainConfig
#      13 from crew.main_algo.main_loop import full_training
#
# /usr/local/lib/python3.12/dist-packages/crew/main_algo/baseline_main_loop.py in <module>
#       7 from jax.tree_util import Partial
#       8
# ----> 9 from crew.main_algo.data_collection_and_agent_updates import (
# ...
